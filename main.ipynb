# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json, os
import cv2 as cv
import shutil
from Utils.cut import dice_coef, df_dice_image, ver_mascara, data_analysis

# %%
path_person="nchavez"
df= data_analysis(path_person=path_person)
df.head(10)

# %%
pic_name="P38C3"
ver_mascara(f"{path_person}/df_{path_person}.csv",pic_name)
